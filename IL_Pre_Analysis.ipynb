# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
  from google.colab import drive
  IN_COLAB = True
except:
  IN_COLAB = False 
  os.chdir("F:\My Drive\Shared\CS 498 Projects\Final Project\Data")
if IN_COLAB:
  drive.mount('/content/drive')
  os.chdir("/content/drive/My Drive/Shared/CS 498 Projects/Final Project/Data")
df_data = pd.read_csv('Illinois/Cleaned_Weather/all_data@IL_1950-2019.csv',
                      sep=',',na_values=-99)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df_data
# Out:
#       Year      County  SeasonalPrep  ...          GDD  Value_soybean  Value_corn
# 0     1950       ADAMS    481.046667  ...  2708.500834           28.0        55.0
# 1     1950       BROWN    446.610000  ...  2691.950000           24.5        53.0
# 2     1950   ALEXANDER    712.876667  ...  3054.285000           19.0        28.0
# 3     1950        BOND    480.830000  ...  2727.100000           20.0        45.0
# 4     1950       BOONE    685.080000  ...  2409.375000           24.0        55.0
# ...    ...         ...           ...  ...          ...            ...         ...
# 7135  2019   WHITESIDE    971.698771  ...  2625.972223            NaN       192.0
# 7136  2019        WILL   1034.590348  ...  2684.305556           47.8         NaN
# 7137  2019  WILLIAMSON    772.109200  ...  3112.222223            NaN       145.4
# 7138  2019   WINNEBAGO    997.407704  ...  2664.444445           55.8       191.8
# 7139  2019    WOODFORD    820.735081  ...  2786.111112           61.4       183.6
#
# [7140 rows x 14 columns]

# %%
correleation_df = df_data.corr(method ='pearson') 
correleation_df = correleation_df.abs()
correleation_df
# Out:
#                      Year  SeasonalPrep  ...  Value_soybean  Value_corn
# Year             1.000000      0.248714  ...       0.789258    0.829856
# SeasonalPrep     0.248714      1.000000  ...       0.286815    0.271795
# SeasonalTmax     0.175287      0.401015  ...       0.381504    0.425375
# SeasonalTmin     0.137175      0.186310  ...       0.013693    0.033752
# SeasonalAvgTmax  0.131224      0.265498  ...       0.347533    0.356360
# SeasonalAvgTmin  0.084746      0.101580  ...       0.145113    0.144639
# WetDays          0.209360      0.479965  ...       0.255422    0.243393
# DaysA30          0.145491      0.318776  ...       0.380106    0.408362
# DaysB10          0.074956      0.136789  ...       0.100568    0.087740
# DaysB_2          0.072721      0.143400  ...       0.014868    0.033960
# GDD              0.014440      0.068763  ...       0.236356    0.241313
# Value_soybean    0.789258      0.286815  ...       1.000000    0.923169
# Value_corn       0.829856      0.271795  ...       0.923169    1.000000
#
# [13 rows x 13 columns]

# %%
correleation_df.apply(lambda row: row.nlargest(2).values[-1],axis=1)
# Out:
# Year               0.829856
# SeasonalPrep       0.479965
# SeasonalTmax       0.698337
# SeasonalTmin       0.680754
# SeasonalAvgTmax    0.931901
# SeasonalAvgTmin    0.940027
# WetDays            0.479965
# DaysA30            0.925250
# DaysB10            0.932266
# DaysB_2            0.680754
# GDD                0.940027
# Value_soybean      0.923169
# Value_corn         0.923169
# dtype: float64

# %%
sns.pairplot(df_data, hue = 'Year')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
for col in df_data.columns:
  plt.plot(df_data['Year'], df_data[col])
  plt.xlabel('Year')
  plt.ylabel(col)
  plt.show()

# %%
df_data.isnull().sum()
# Out:
# Year                 0
# County               0
# SeasonalPrep         0
# SeasonalTmax         0
# SeasonalTmin         0
# SeasonalAvgTmax      0
# SeasonalAvgTmin      0
# WetDays              0
# DaysA30              0
# DaysB10              0
# DaysB_2              0
# GDD                  0
# Value_soybean      103
# Value_corn         112
# dtype: int64
